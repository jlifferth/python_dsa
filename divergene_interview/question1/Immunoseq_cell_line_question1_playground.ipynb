# %%
import pandas as pd
import seaborn as sns

# %%
url = 'https://drive.google.com/file/d/1UqwhclZtkAI3UDWaguzNj1VfFGpylDrF/view?usp=sharing'
url = 'https://drive.google.com/uc?id=1UqwhclZtkAI3UDWaguzNj1VfFGpylDrF'

df = pd.read_csv(url)
df
# Out:
#      SampleID Region Population HLA-A 1 HLA-A 2 HLA-B 1 HLA-B 2 HLA-C 1  \
# 0     HG01879    AFR        ACB   23:01   68:02   13:02   42:01   08:04
# 1     HG01880    AFR        ACB   33:03   68:02   40:06   42:01   12:02
# 2     HG01882    AFR        ACB   23:01   34:02   07:02   44:50   04:01
# 3     HG01883    AFR        ACB   02:01   68:02   53:01   44:03   04:01
# 4     HG01885    AFR        ACB   03:01   33:03   35:01   35:01   04:01
# ...       ...    ...        ...     ...     ...     ...     ...     ...
# 2499  HG04106    SAS        STU   01:01   02:01   18:01   35:01   04:01
# 2500  HG04107    SAS        STU   11:01   33:03   57:01   40:06   06:02
# 2501  HG04210    SAS        STU   02:01   24:02   15:25   35:01   04:01
# 2502  HG04227    SAS        STU   01:01   01:01   57:01   44:03   06:02
# 2503  HG04229    SAS        STU   11:01   24:07   13:01   37:01   04:03
#
#      HLA-C 2 HLA-DQB1 1 HLA-DQB1 2 HLA-DRB1 1 HLA-DRB1 2
# ...

# %%
df.columns
# Out:
# Index(['SampleID', 'Region', 'Population', 'HLA-A 1', 'HLA-A 2', 'HLA-B 1',
#        'HLA-B 2', 'HLA-C 1', 'HLA-C 2', 'HLA-DQB1 1', 'HLA-DQB1 2',
#        'HLA-DRB1 1', 'HLA-DRB1 2'],
#       dtype='object')

# %%
client_list = ['A*01:01', 'A*02:01', 'A*03:01', 'A*11:01', 'A*23:01', 'A*24:02', 'A*26:01', 'A*29:02', 'A*30:01', 'A*30:02', 'A*31:01', 'A*32:01', 'A*33:03', 'A*68:01', 'A*68:02', 'B*35:01', 'B*07:02', 'B*40:01', 'B*08:01', 'B*44:03', 'B*51:01', 'B*53:01', 'B*44:02', 'B*15:01', 'B*18:01', 'B*58:01', 'B*14:02', 'B*27:05', 'B*15:03', 'B*48:01', 'B*52:01', 'B*42:01', 'B*49:01', 'B*57:01', 'B*13:02', 'B*39:01', 'B*40:02', 'B*58:02', 'B*46:01', 'B*35:03', 'B*57:03', 'B*38:01', 'B*15:10', 'B*50:01', 'B*55:01', 'B*15:02', 'B*37:01', 'B*54:01', 'B*38:02', 'B*45:01', 'B*81:01', 'B*07:05', 'B*14:01', 'B*35:02']

client_list
# Out:
# ['A*01:01',
#  'A*02:01',
#  'A*03:01',
#  'A*11:01',
#  'A*23:01',
#  'A*24:02',
#  'A*26:01',
#  'A*29:02',
#  'A*30:01',
#  'A*30:02',
#  'A*31:01',
#  'A*32:01',
#  'A*33:03',
#  'A*68:01',
#  'A*68:02',
#  'B*35:01',
#  'B*07:02',
#  'B*40:01',
#  'B*08:01',
#  'B*44:03',
#  'B*51:01',
#  'B*53:01',
#  'B*44:02',
#  'B*15:01',
#  'B*18:01',
#  'B*58:01',
#  'B*14:02',
#  'B*27:05',
#  'B*15:03',
#  'B*48:01',
#  'B*52:01',
#  'B*42:01',
#  'B*49:01',
#  'B*57:01',
#  'B*13:02',
#  'B*39:01',
#  'B*40:02',
#  'B*58:02',
#  'B*46:01',
#  'B*35:03',
#  'B*57:03',
#  'B*38:01',
#  'B*15:10',
#  'B*50:01',
#  'B*55:01',
#  'B*15:02',
#  'B*37:01',
#  'B*54:01',
#  'B*38:02',
#  'B*45:01',
#  'B*81:01',
#  'B*07:05',
#  'B*14:01',
#  'B*35:02']

# %%
# preliminary loop to see how many matches appear for target alleles
client_list = ['A*01:01', 'A*02:01', 'A*03:01', 'A*11:01', 'A*23:01', 'A*24:02', 'A*26:01', 'A*29:02', 'A*30:01', 'A*30:02', 'A*31:01', 'A*32:01', 'A*33:03', 'A*68:01', 'A*68:02', 'B*35:01', 'B*07:02', 'B*40:01', 'B*08:01', 'B*44:03', 'B*51:01', 'B*53:01', 'B*44:02', 'B*15:01', 'B*18:01', 'B*58:01', 'B*14:02', 'B*27:05', 'B*15:03', 'B*48:01', 'B*52:01', 'B*42:01', 'B*49:01', 'B*57:01', 'B*13:02', 'B*39:01', 'B*40:02', 'B*58:02', 'B*46:01', 'B*35:03', 'B*57:03', 'B*38:01', 'B*15:10', 'B*50:01', 'B*55:01', 'B*15:02', 'B*37:01', 'B*54:01', 'B*38:02', 'B*45:01', 'B*81:01', 'B*07:05', 'B*14:01', 'B*35:02']

for haplotype in client_list:
    locus = haplotype[0]
    allele = haplotype[2:]
    if locus == 'A':
        match = df[(df['HLA-A 1'] == allele) | (df['HLA-A 2'] == allele)]
        print(haplotype)
        print(len(match))
    elif locus == 'B':
        match = df[(df['HLA-B 1'] == allele) | (df['HLA-B 2'] == allele)]
        print(haplotype)
        print(len(match))
#     print(locus, allele)
# Out:
# A*01:01
# 356
# A*02:01
# 638
# A*03:01
# 328
# A*11:01
# 425
# A*23:01
# 164
# A*24:02
# 464
# A*26:01
# 132
# A*29:02
# 101
# A*30:01
# 140
# A*30:02
# 128
# A*31:01
# 125
# A*32:01
# 107
# A*33:03
# 246
# A*68:01
# 177
# A*68:02
# 108
# B*35:01
# 284
# B*07:02
# 282
# B*40:01
# 179
# B*08:01
# 184
# B*44:03
# 263
# B*51:01
# 248
# B*53:01
# 201
# B*44:02
# 116
# B*15:01
# 116
# B*18:01
# 124
# B*58:01
# 165
# B*14:02
# 60
# B*27:05
# 59
# B*15:03
# 81
# B*48:01
# 40
# B*52:01
# 168
# B*42:01
# 70
# B*49:01
# 74
# B*57:01
# 151
# B*13:02
# 71
# B*39:01
# 34
# B*40:02
# 70
# B*58:02
# 36
# B*46:01
# 134
# B*35:03
# 94
# B*57:03
# 49
# B*38:01
# 35
# B*15:10
# 59
# B*50:01
# 52
# B*55:01
# 43
# B*15:02
# 88
# B*37:01
# 45
# B*54:01
# 28
# B*38:02
# 48
# B*45:01
# 73
# B*81:01
# 27
# B*07:05
# 31
# B*14:01
# 22
# B*35:02
# 31

# %%
# create seperate allele lists
A_allele_list = []
B_allele_list = []

for haplotype in client_list:
    locus = haplotype[0]
    allele = haplotype[2:]
    if locus == 'A':
        A_allele_list.append(allele)
    elif locus == 'B':
        B_allele_list.append(allele)

print(len(A_allele_list), len(B_allele_list))
# Out:
# 15 39

# %%
# let's focus on which samples have the most allele matches

target_columns = ['HLA-A 1', 'HLA-A 2', 'HLA-B 1', 'HLA-B 2']
samples = df.SampleID.unique()

# %%
match_counts = {}
for sample in samples:
    print(sample)
    match_count = 0
    row = df[(df['SampleID'] == sample)].values[0]
    for A_allele in A_allele_list:
        if A_allele == row[3] or A_allele == row[4]:
            print('A_allele match: ', A_allele)
            match_count += 1
    for B_allele in B_allele_list:
        if B_allele == row[5] or B_allele == row[6]:
            print('B_allele match: ', B_allele)
            match_count += 1
    print('match count: ', match_count)
    match_counts[sample] = match_count
# Out:
# HG01879
# A_allele match:  23:01
# A_allele match:  68:02
# B_allele match:  42:01
# B_allele match:  13:02
# match count:  4
# HG01880
# A_allele match:  33:03
# A_allele match:  68:02
# B_allele match:  42:01
# match count:  3
# HG01882
# A_allele match:  23:01
# B_allele match:  07:02
# match count:  2
# HG01883
# A_allele match:  02:01
# A_allele match:  68:02
# B_allele match:  44:03
# B_allele match:  53:01
# match count:  4
# HG01885
# A_allele match:  03:01
# A_allele match:  33:03
# B_allele match:  35:01
# match count:  3
# HG01886
# A_allele match:  30:02
# B_allele match:  15:03
# B_allele match:  57:03
# match count:  3
# HG01889
# A_allele match:  30:01
# A_allele match:  30:02
# B_allele match:  58:01
# B_allele match:  42:01
# match count:  4
# HG01890
# A_allele match:  01:01
# A_allele match:  30:01
# B_allele match:  07:02
# match count:  3
# HG01894
# A_allele match:  23:01
# B_allele match:  53:01
# match count:  2
# HG01896
# A_allele match:  23:01
# ...

# %%
len(match_counts)
# Out:
# 2504

# %%
sns.displot(match_counts).set(title="Wow! Almost all of these cell lines have at least one match, that's great")

# %%
client_list_matches = {}
for haplotype in client_list:
    client_list_matches[haplotype] = 0

# %%
# client_list_matches

# %%
# full search algorithm v1
# this list contains cell lines that satisfy a client list requirement and should be ordered
cell_order_list = []

for sample in samples:
    
    # we begin iteration with default assumption that sample does not satisfy requirement until proven otherwise
    
    order_sample = False
    row = df[(df['SampleID'] == sample)].values[0]
    A1 = 'A*' + row[3]
    A2 = 'A*' + row[4]
    B1 = 'B*' + row[5]
    B2 = 'B*' + row[6]
    row_alleles = [A1, A2, B1, B2]
#     print(row_alleles)
    
    # determine if this cell line satisfies any client alleles that have not yet been matched
    for allele in row_alleles:
        if allele in client_list_matches:
            if client_list_matches[allele] == 0:
                order_sample = True
    
    if order_sample:
        print('Order sample: ', sample)
        cell_order_list.append(sample)
        for allele in row_alleles:
            if allele in client_list_matches:
                client_list_matches[allele] += 1
    else:
        print('Do not order sample: ', sample)
# Out:
# Order sample:  HG01879
# Order sample:  HG01880
# Order sample:  HG01882
# Order sample:  HG01883
# Order sample:  HG01885
# Order sample:  HG01886
# Order sample:  HG01889
# Order sample:  HG01890
# Do not order sample:  HG01894
# Do not order sample:  HG01896
# Order sample:  HG01912
# Order sample:  HG01914
# Do not order sample:  HG01915
# Order sample:  HG01956
# Do not order sample:  HG01958
# Do not order sample:  HG01985
# Do not order sample:  HG01986
# Order sample:  HG01988
# Do not order sample:  HG01989
# Order sample:  HG01990
# Order sample:  HG02009
# Order sample:  HG02010
# Order sample:  HG02012
# Do not order sample:  HG02013
# Do not order sample:  HG02014
# Order sample:  HG02051
# Do not order sample:  HG02052
# Do not order sample:  HG02053
# Do not order sample:  HG02054
# Do not order sample:  HG02095
# Order sample:  HG02107
# Order sample:  HG02108
# Do not order sample:  HG02111
# Do not order sample:  HG02143
# Order sample:  HG02144
# ...

# %%
len(cell_order_list)
# Out:
# 44

# %%
# client_list_matches

# %%
# full search algorithm v2 - optimize to start by selecting cell lines with higher match counts
# this list contains cell lines that satisfy a client list requirement and should be ordered
cell_order_list2 = []

client_list_matches2 = {}
for haplotype in client_list:
    client_list_matches2[haplotype] = 0

i = 4
while i > 0:
    for cell_line in match_counts:
        if match_counts[cell_line] == i:
            
            # we begin iteration with default assumption that sample does not satisfy requirement until proven otherwise
            order_sample = False
            row = df[(df['SampleID'] == cell_line)].values[0]
            A1 = 'A*' + row[3]
            A2 = 'A*' + row[4]
            B1 = 'B*' + row[5]
            B2 = 'B*' + row[6]
            row_alleles = [A1, A2, B1, B2]

            # determine if this cell line satisfies any client alleles that have not yet been matched
            for allele in row_alleles:
                if allele in client_list_matches:
                    if client_list_matches2[allele] == 0:
                        order_sample = True

            if order_sample:
                print('Order sample: ', cell_line)
                cell_order_list2.append(cell_line)
                for allele in row_alleles:
                    if allele in client_list_matches:
                        client_list_matches2[allele] += 1
            else:
                print('Do not order sample: ', cell_line)
    i -= 1
# Out:
# Order sample:  HG01879
# Order sample:  HG01883
# Order sample:  HG01889
# Order sample:  HG01912
# Order sample:  HG01985
# Order sample:  HG01988
# Order sample:  HG02282
# Order sample:  HG02323
# Order sample:  HG02325
# Order sample:  HG02330
# Order sample:  HG02334
# Order sample:  HG02339
# Order sample:  HG02343
# Order sample:  HG02420
# Order sample:  HG02429
# Do not order sample:  HG02449
# Order sample:  HG02455
# Do not order sample:  HG02479
# Order sample:  HG02485
# Do not order sample:  HG02496
# Do not order sample:  HG02497
# Order sample:  HG02501
# Do not order sample:  HG02505
# Do not order sample:  HG02557
# Do not order sample:  NA19700
# Do not order sample:  NA19703
# Order sample:  NA19704
# Do not order sample:  NA19711
# Do not order sample:  NA19712
# Do not order sample:  NA19819
# Order sample:  NA19835
# Order sample:  NA19904
# Order sample:  NA19913
# Order sample:  NA19921
# Do not order sample:  NA19922
# Order sample:  NA19982
# ...

# %%
len(cell_order_list2)
# Out:
# 38

# %%
client_list_matches2
# Out:
# {'A*01:01': 3,
#  'A*02:01': 15,
#  'A*03:01': 6,
#  'A*11:01': 4,
#  'A*23:01': 9,
#  'A*24:02': 4,
#  'A*26:01': 4,
#  'A*29:02': 3,
#  'A*30:01': 3,
#  'A*30:02': 8,
#  'A*31:01': 3,
#  'A*32:01': 1,
#  'A*33:03': 3,
#  'A*68:01': 3,
#  'A*68:02': 7,
#  'B*35:01': 4,
#  'B*07:02': 2,
#  'B*40:01': 1,
#  'B*08:01': 1,
#  'B*44:03': 3,
#  'B*51:01': 3,
#  'B*53:01': 8,
#  'B*44:02': 5,
#  'B*15:01': 2,
#  'B*18:01': 2,
#  'B*58:01': 5,
#  'B*14:02': 2,
#  'B*27:05': 1,
#  'B*15:03': 2,
#  'B*48:01': 1,
#  'B*52:01': 2,
#  'B*42:01': 4,
#  'B*49:01': 1,
#  'B*57:01': 1,
#  'B*13:02': 2,
#  'B*39:01': 1,
#  'B*40:02': 1,
#  'B*58:02': 1,
#  'B*46:01': 2,
#  'B*35:03': 1,
#  'B*57:03': 1,
#  'B*38:01': 1,
#  'B*15:10': 3,
#  'B*50:01': 2,
#  'B*55:01': 1,
#  'B*15:02': 1,
#  'B*37:01': 1,
#  'B*54:01': 1,
#  'B*38:02': 1,
#  'B*45:01': 2,
#  'B*81:01': 1,
#  'B*07:05': 1,
#  'B*14:01': 1,
#  'B*35:02': 1}

# %%
# brainstorm space below

# %%
df.iloc[[0]]
# Out:
#   SampleID Region Population HLA-A 1 HLA-A 2 HLA-B 1 HLA-B 2 HLA-C 1 HLA-C 2  \
# 0  HG01879    AFR        ACB   23:01   68:02   13:02   42:01   08:04   17:01
#
#   HLA-DQB1 1 HLA-DQB1 2 HLA-DRB1 1 HLA-DRB1 2
# 0      02:02      04:02      03:02      09:01

# %%
row = df[(df['SampleID'] == samples[0])]
row
# Out:
#   SampleID Region Population HLA-A 1 HLA-A 2 HLA-B 1 HLA-B 2 HLA-C 1 HLA-C 2  \
# 0  HG01879    AFR        ACB   23:01   68:02   13:02   42:01   08:04   17:01
#
#   HLA-DQB1 1 HLA-DQB1 2 HLA-DRB1 1 HLA-DRB1 2
# 0      02:02      04:02      03:02      09:01

# %%
row.values
# Out:
# array([['HG01879', 'AFR', 'ACB', '23:01', '68:02', '13:02', '42:01',
#         '08:04', '17:01', '02:02', '04:02', '03:02', '09:01']],
#       dtype=object)

# %%
value = row['HLA-A 1'].values[0]
print(value)
# Out:
# 23:01

# %%
query = A_allele_list[4]

# %%
row['HLA-A 1'].values == A_allele_list[4]
# Out:
# array([ True])

# %%
value == query
# Out:
# True

# %%
value in query
# Out:
# True

# %%
query in value
# Out:
# True

# %%
value in A_allele_list
# Out:
# True
